# %%
import requests
import pandas as pd
from tabulate import tabulate
import re

# %%
# Initialize an empty list to store all project data
extracted_data = []
base_url = "https://gateway.chotot.com/v1/public/api-pty/project"
limit = 200
offset = 0
offset_item = 0

while offset <= 4150:
    # Construct URL with current offset and limit
    url = f"{base_url}?limit={limit}&offset={offset}"

    # Make request
    response = requests.get(url)

    # Check if request is successful
    if response.status_code == 200:
        # Convert the JSON response content into a Python dictionary
        data = response.json()
        # Retrieve projects from the response data
        projects = data.get('projects', [])
        offset += limit
        # Adjust offset for the last request
        if offset == 4000:
            limit = 150 
    else:
        print("Error fetching data")
        break

    # Process each project
    for i, project in enumerate(projects):
        # Extract facilities and surrounding
        facilities = project.get('facilities', [])
        # surrounding = project.get('surrounding', [])

        facilities_key = [facility.get('key') for facility in facilities if isinstance(facility, dict)]
        surrounding_key = project.get('surrounding', [])

        # Extract content from short_introduction or introduction
        short_introduction = project.get('short_introduction', [])
        introduction = project.get('introduction', '')

        if not isinstance(short_introduction, str) or not short_introduction:
            # If short_introduction is not a string or empty list, use introduction
            content = re.sub('<[^<]+?>', '', introduction).strip()
        else:
            # Use regex to extract text content within HTML tags
            content = re.sub('<[^<]+?>', '', short_introduction).strip()

        # Update URL for the current project with its specific offset
        project_url = f"{base_url}?limit=1&offset={offset_item}"
        offset_item += 1  # Increment offset_item for the next individual item

        # Create dictionary for extracted data
        extracted_project_data = {
            'project_oid': project.get('project_oid', ''),
            'area_v2': project.get('area_name', ''),
            'web_url': project.get('web_url', ''),
            'facilities_key': facilities_key,
            'surrounding_key': surrounding_key,
            'investor_id': project.get('investor_id', ''),
            'investor_name': project.get('investor_name', ''),
            'paid_time': project.get('paid_time', ''),
            'short_introduction_content': content,
            'full_url_with_params': project_url  # Use current URL with specific params
        }

        # Append extracted data to list
        extracted_data.append(extracted_project_data)

# Print attributes in tabular format for the first 5 rows
if extracted_data:
    headers = extracted_data[0].keys()
    rows = [list(project.values()) for project in extracted_data[:5]]  # Print only first 5 rows
    print(tabulate(rows, headers=headers, tablefmt="grid"))
else:
    print("No data fetched")

# Export data to CSV file
csv_filename = "projects_data.csv"
df = pd.DataFrame(extracted_data)
df.to_csv(csv_filename, index=False)

print(f"Data exported to {csv_filename}")
# Out:
# +---------------+-----------------------+--------------------------------------------------------------------------------------+------------------------------------------------------------+----------------------------------------+---------------+------------------------------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+
# |   project_oid | area_v2               | web_url                                                                              | facilities_key                                             | surrounding_key                        |   investor_id | investor_name                |     paid_time | short_introduction_content                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | full_url_with_params                                                  |
# +===============+=======================+======================================================================================+============================================================+========================================+===============+==============================+===============+===========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+=======================================================================+
# |    1582239957 | Huyện Nhơn Trạch      | https://www.nhatot.com/du-an-khu-do-thi-dta-nhon-trach-huyen-nhon-trach-pj1582239957 | ['play_ground', 'fire_alarm', 'elevator', 'parkings']      | ['school', 'hospital', 'atm', 'banks'] |           378 | Công ty Cổ phần Đệ Tam (DTA) | 1500192200337 | 1.Vị trí:Dự án khu đô thị DETACO NHƠN TRẠCH của Công ty CP Đệ Tam (DETACO) có quy mô rộng 47,3 ha thuộc địa phận Xã Phước An, huyện Nhơn Trạch, tỉnh Đồng Nai, nằm trong khu quy hoạch tổng thể Thành phố Nhơn Trạch2.Tiện ích:Nội khu:&nbsp;Trường học, bệnh viện,công viên, cửa hàng tiện ích, trung tâm thương mại....Ngoại khu:cách 500 m là Công viên Thế giới tuổi thơ qui mô 150 ha, công viên khu vực qui 50 ha, TT thể dục thể thao (HUD); Sấn bay quốc tế Long Thành qui mô 5000 ha3.Chính sách ưu đãi:Ngân hàng MHB bảo lãnh dự án hỗ trợ cho vay đến 80% giá trị căn hộ, lãi suất cố định 5%/năm trong suốt 15 năm.4.Chủ đầu tư uy tín:Công ty Cổ phần Đệ TamCác dự án: Dự án chung cư Tân Phước, Biệt thự Detaco Phú quốc....                                                                                                                                                                                                                                                                                                                                                                                                                                                                | https://gateway.chotot.com/v1/public/api-pty/project?limit=1&offset=0 |
# +---------------+-----------------------+--------------------------------------------------------------------------------------+------------------------------------------------------------+----------------------------------------+---------------+------------------------------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+
# |     405530665 | Huyện Văn Giang       | https://www.nhatot.com/du-an-khu-do-thi-ecopark-huyen-van-giang-pj405530665          | ['shopping_center', 'sports_area', 'spa', 'swimming_pool'] | []                                     |           975 | Vihajico                     | 1489981484830 | 1.Vị trí:Nằm tại Khu vực Đông Nam của Thành phố Hà Nội liền kề với làng gốm Bát Tràng, chỉ cách trung tâm thủ đô Hà Nội 12,8kmNằm tại huyện Văn Giang, tỉnh Hưng Yên, liền kề làng gốm Bát Tràng, cách trung tâm thủ đô Hà Nội 12.8 km.2.Tiện ích:Nội khu: &nbsp;phòng khám Eco Clinic, trường phổ thông liên cấp Đoàn Thị Điểm, những khu phố cổ, những viện bảo tàng, trường mỹ thuật, các tượng đài lịch sử và quảng trường văn hóa...Ngoại khu:&nbsp;Học viện Golf EPGA, Khu liên hợp thể thao Ecopark Sports Arena, Trường liên cấp Nguyễn Siêu...3.Chính sách ưu đãi:Phương thức 1: thanh toán 15 đợt theo các mức: 30% – 20% – 45% – 5%, trong đó riêng đợt thanh toán 20% khách hàng được phép chia thành 11 lần trong vòng 12 tháng, tức là chỉ phải trả 1,67%/ tháng.Phương thức thanh toán thứ 2 theo tiến độ: 50% – 45% – 5%, khách hàng mua những căn nhỏ (căn số 02 và 09) sẽ được hưởng chiết khấu 2% tổng GTCH4.Chủ đầu tư:Công ty cổ phần đầu tư và phát triển đô thị Việt Hưng (Vihajico)                                                                                                                                                                                               | https://gateway.chotot.com/v1/public/api-pty/project?limit=1&offset=1 |
# +---------------+-----------------------+--------------------------------------------------------------------------------------+------------------------------------------------------------+----------------------------------------+---------------+------------------------------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+
# |    1728959123 | Huyện Bình Chánh      | https://www.nhatot.com/du-an-nam-phong-eco-park-huyen-binh-chanh-pj1728959123        | ['play_ground']                                            | []                                     |           975 | Vihajico                     | 1507216430585 | 1.Vị tr&iacute;:nằm ngay trục đường ch&iacute;nh nối về c&aacute;c tỉnh miền T&acirc;y, đ&acirc;y l&agrave; tuyến giao th&ocirc;ng huyết mạch kết nối TP.HCM với c&aacute;c tỉnh khu vực miền T&acirc;y thuận lợi cho việc đi lại của cư d&acirc;n cũng như giao thương mua b&aacute;n.&nbsp;C&aacute;ch cụm KCN Phước Đ&ocirc;ng, Kiến Ph&aacute;t, Thuận Đạo, Cầu Tr&agrave;m 10 ph&uacute;t.Tọa lạc ngay trung t&acirc;m thị trấn Cần Đước.Từ dự &aacute;n Nam Phong Eco Town, cư d&acirc;n c&oacute; thể:- Đ&oacute;n nhiều tuyến xe bu&yacute;t đi về trung t&acirc;m th&agrave;nh phố ngang khu d&acirc;n cư.- Chỉ 20 ph&uacute;t về chợ đầu mối B&igrave;nh Điền, BigC An Lạc, Bến xe Miền T&acirc;y,&hellip;- Đi quận 7, quận 8 bằng Đại Lộ Nguyễn Văn Linh th&ocirc;ng tho&aacute;ng chỉ 30 ph&uacute;t đi xe, về Quận 1 chỉ 45 ph&uacute;t bằng Đại Lộ V&otilde; Văn Kiệt.- Về quận B&igrave;nh T&acirc;n, quận 5, quận 6, quận 11 chỉ 25 ph&uacute;t bằng đường Quốc lộ 1A, đường dẫn cao tốc S&agrave;i G&ograve;n &ndash; Trung Lương.2.Tiện &iacute;ch:C&Ocirc;NG VI&Ecirc;N - PHỐ ĐI BỘKHU SINH TH&Aacute;ITRƯỜNG HỌCKHU VUI CHƠI TRẺ EMS&Acirc;N B&Oacute;NG Đ&Aacute; NAM PHONG ECO TOWN | https://gateway.chotot.com/v1/public/api-pty/project?limit=1&offset=2 |
# +---------------+-----------------------+--------------------------------------------------------------------------------------+------------------------------------------------------------+----------------------------------------+---------------+------------------------------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+
# |    1086443687 | Huyện Cần Giờ         | https://www.nhatot.com/du-an-vinhomes-long-beach-can-gio-huyen-can-gio-pj1086443687  | []                                                         | []                                     |            53 | Tập đoàn Vingroup            | 1675008369985 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | https://gateway.chotot.com/v1/public/api-pty/project?limit=1&offset=3 |
# +---------------+-----------------------+--------------------------------------------------------------------------------------+------------------------------------------------------------+----------------------------------------+---------------+------------------------------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+
# |     914252993 | Thành phố Thủ Dầu Một | https://www.nhatot.com/du-an-capitaland-binh-duong-thanh-pho-thu-dau-mot-pj914252993 | []                                                         | []                                     |           190 | Tập đoàn CapitaLand          | 1675010888324 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | https://gateway.chotot.com/v1/public/api-pty/project?limit=1&offset=4 |
# +---------------+-----------------------+--------------------------------------------------------------------------------------+------------------------------------------------------------+----------------------------------------+---------------+------------------------------+---------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+
# Data exported to projects_data.csv
